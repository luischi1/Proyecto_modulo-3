# %% [markdown]
# # Título

# %% [markdown]
# ## Objetivos

# %% [markdown]
# ### Objetivo General

# %% [markdown]
# ### Objetivos Específicos

# %% [markdown]
# ## Modelo

# %% [markdown]
# Se considera un sistema ecológico simple, compuesto solamente por dos especies: correcaminos $(x_1)$ y coyotes $(x_2)$ y, donde los coyotes se alimentan de los correcaminos.
#
# Los tamaños de las poblaciones cambian de acuerdo con las ecuaciones:
#
# $$dx_1/dt=k_1x_1-k_2x_1x_2$$
#
# $$dx_2/dt=k_3x_1x_2-k_4x_2$$
#
# Que se entienden de la siguiente forma:
# - si no hay coyotes $(x_2)$, los correcaminos $(x_1)$ se reproducen con una velocidad de crecimiento $k_1x_1$
# - Si no hay correcaminos $(x_1)$, la especie de coyotes desaparece con velocidad $k_4x_2$.
# - El término $x_1x_2$ representa la interacción entre las dos especies
# - Las constantes $k_2$ y $k_3$ dependen de la habilidad de los depredadores para atrapar a su presa y la habilidad de las presas para huir.
# - Las poblaciones de los coyotes y los correcaminos cambian cíclicamente.
#
# Si se tienen los siguientes valores:
# - $k_1=0.4$
# - $k_2=0.02$
# - $k_3=0.001$
# - $k_4=0.3$
#
# Y las siguientes condiciones iniciales:
# $$x_1(0)=30$$
# $$x_2(0)=3$$
#
# Determine la cantidad de cada especie en $t=2$

# %% [markdown]
# ## Simulaciones 1

# %% [markdown]
# Con las primeras K y las primeras condiciones iniciales...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy.integrate import odeint

# %% [markdown]
# #### Simulación 1

# %%
k1=0.4
k2=0.02
k3=0.001
k4=0.3

# %%
def eco(x, t):
    x1 = x[0]
    x2 = x[1]
    dx1 = k1*x1-k2*x1*x2
    dx2 = k3*x1*x2-k4*x2
    return np.array([dx1, dx2])

# %%
# Primer condición inicial
x0 = np.array([30, 3])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# Como podemos observar, al no haber mucha población de coyotes, los correcaminos comienzan a incrementar la suya, más rápido de lo que los coyotes pueden cazar, debido a que, según la cantidad de estos, los coyotes reducen su capacidad de atrapar y los correcaminos incrementan su habilidad de huir.

# %% [markdown]
# #### Simulación 2
#
# Ahora tendremos el mismo número de coyotes que de correcaminos.
# $$x_1(0)=15$$
# $$x_2(0)=15$$

# %%
# Primer condición inicial
x0 = np.array([15, 15])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# Como podemos observar, si ambos comienzan en la misma cantidad, los correcaminos incrementan mientras que los coyotes se reducen. Esto debido a que, como los correcaminos poseen mayor rapidez al reproducirse que los coyotes, incrementan más rápido su habilidad para huir que los coyotes para cazarlos.

# %% [markdown]
# #### Simulación 3

# %% [markdown]
# Ahora tendremos el mayor número de coyotes que de correcaminos, volteando las condiciones de la Simulación 1.
# $$x_1(0)=3$$
# $$x_2(0)=30$$

# %%
# Primer condición inicial
x0 = np.array([3, 30])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# Como no hay correcaminos, la población de los coyotes disminuye con mucha rapidez

# %% [markdown]
# #### Simulación 4
#
# Ahora tendremos el mayor número de correcaminos que de coyotes, pero de forma más equilibrada
# $$x_1(0)=20$$
# $$x_2(0)=15$$

# %%
# Primer condición inicial
x0 = np.array([20, 15])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# #### Simulación 5
#
# Ahora tendremos el mayor número de coyotes que de correcaminos, pero de forma más equilibrada
# $$x_1(0)=15$$
# $$x_2(0)=20$$

# %%
# Primer condición inicial
x0 = np.array([15, 20])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ## Simulaciones 2
#
# Como pudimos observar anteriormente, los coyotes fueron los menos favorecidos en todos los escenarios planteados, esto debido a las k que manejaba el sistema. Ahora, lo que haremos será cambiar los valores de k para beneficiar a los coyotes y observar el cambio en estas simulaciones. Los haremos más resistentes.

# %%
k1=0.4
k2=0.001
k3=0.02
k4=0.1

# %% [markdown]
# ### Simulación 6
#
# Usaremos los valores iniciales originales del ejercicio
# $$x_1(0)=30$$
# $$x_2(0)=3$$

# %%
# Primer condición inicial
x0 = np.array([30, 3])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ### Simulación 7
#
# Ahora tendremos el mismo número de coyotes que de correcaminos.
# $$x_1(0)=15$$
# $$x_2(0)=15$$

# %%
# Primer condición inicial
x0 = np.array([15, 15])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ### Simulación 8
#
# Ahora tendremos el mayor número de coyotes que de correcaminos, volteando las condiciones de la Simulación 1.
# $$x_1(0)=3$$
# $$x_2(0)=30$$

# %%
# Primer condición inicial
x0 = np.array([3, 30])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ### Simulación 9
#
# Ahora tendremos el mayor número de correcaminos que de coyotes, pero de forma más equilibrada
# $$x_1(0)=20$$
# $$x_2(0)=15$$

# %%
# Primer condición inicial
x0 = np.array([20, 15])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ### Simulación 10
#
# Ahora tendremos el mayor número de coyotes que de correcaminos, pero de forma más equilibrada
# $$x_1(0)=15$$
# $$x_2(0)=20$$

# %%
# Primer condición inicial
x0 = np.array([15, 20])
# Vector de tiempo
t = np.linspace(0, 2, 100)

# %%
# Resolver numéricamente
xx = odeint(eco, x0, t)
# Separamos soluciones
x1 = xx[:, 0]
x2 = xx[:, 1]

# %%
plt.figure(figsize=(8,6))
plt.plot(t, x1, label='Población de correcaminos $x_1(t)$')
plt.plot(t, x2, label='Población de coyotes $x_2(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(x1, x2, label='Trayectoria de las poblaciones')
plt.plot(x1[0], x2[0], '*', ms=10, label = 'Poblaciones iniciales')
plt.plot(x1[-1], x2[-1], '*', ms=10, label = 'Poblaciones finales')
plt.xlabel('Población de correcaminos $x_1$')
plt.ylabel('Población de coyotes $x_2$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# ## Referencias
